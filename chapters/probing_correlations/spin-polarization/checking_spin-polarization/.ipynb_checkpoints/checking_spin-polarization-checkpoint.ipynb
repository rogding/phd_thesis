# %%
import numpy as np
import pandas as pd
from uncertainties import unumpy, ufloat

import os
import glob

import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import seaborn as sns

from lmfit.models import Model, ConstantModel, PolynomialModel, GaussianModel, VoigtModel, LorentzianModel, PseudoVoigtModel

sns.set_context('talk')

# %%
# https://stackoverflow.com/questions/22348756/upright-mu-in-plot-label-retaining-original-tick-fonts
# https://stackoverflow.com/questions/2537868/sans-serif-math-with-latex-in-matplotlib

import matplotlib
from matplotlib import rc

matplotlib.rc('text', usetex = True)
matplotlib.rc('font', **{'family':'sans-serif'})

params = {'text.latex.preamble':[r'\usepackage{siunitx}',
                                 r'\usepackage{amsmath}',
                                 r'\usepackage{physics}',
                                 r'\usepackage{helvet}',
                                 r'\usepackage{sansmath}',
                                 r'\sansmath',
                                 r'\sisetup{detect-all}']}
plt.rcParams.update(params)

# %%
# List of files to glob
POL_LIST = glob.glob('n33-spin-pol-old_freq-X_bias-2.0V-spectra-lin-lin_pol*_out.csv')
UNPOL_LIST = glob.glob('n33-unpol-X_bias-2.0V-baseline_spectra-lin-lin_pol*_out.csv')

SET_NAME = r'Checking spin-pol with n=33'
POL_NAME = r'n33-unpol-X_bias-2.0V-baseline_spectra-lin-lin_pol'
UNPOL_NAME = r'n33-spin-pol-old_freq-X_bias-2.0V-spectra-lin-lin_pol'

ATOMIC = 1505.45
ZEEMAN = 0
ORDER = 1

SATURATION_A = ufloat(44.0442405, 1.65366925)
SATURATION_B = ufloat(-0.05852900, 0.00456716)
NUM_EXPOSURES = 1000 # Number of excitation loops

# %% [markdown]
# # Retrieve files and do some preprocessing

# %% [markdown]
# ### Retrieve all the data files and put in to a single DataFrame

# %%
# Last modified 2019/04/05
# Goes through all listed .csv files and returns data in a single DataFrame
def gather_data(file_list):
    
    # Read in .csv files in to single DataFrame
    out = pd.DataFrame()
    for file_name in file_list:
        df = pd.read_csv(file_name)
        df['Scan'] = os.path.basename(file_name)
        df['Timestamp'] = pd.to_datetime(df['Timestamp'])
        
        out = pd.concat([out, df], join='outer', ignore_index=True)
    
    return out

pol_data = gather_data(POL_LIST)
unpol_data = gather_data(UNPOL_LIST)

# %% [markdown]
# ### Reduce the data by removing bad points

# %%
# First pass at removing bad data points
def reduce_data(df_data, name, show_plots):
    
    # Remove data where UV laser was not locked based on 'DigiLock_PID1_locked' column
    df_reduced = df_data[df_data['DigiLock_PID1_locked'] >= 4.9]
    
    # Remove data where atom number was above/below cutoff
    df_reduced = df_reduced[(100e3 <= df_reduced['numberAtom']) & (df_reduced['numberAtom'] <= 400e3)]
    
    # Remove data where tempYAtom was above/below cutoff
    df_reduced = df_reduced[(500E-9 <= df_reduced['tempYAtom']) & (df_reduced['tempYAtom'] <= 1.2E-6)]
    
    # Plotting original and reduced data sets
    df_orig = df_data.sort_values(by=['Timestamp'])
    df_redu = df_reduced.sort_values(by=['Timestamp'])
    
    if show_plots:
        [fig, ax]= plt.subplots(nrows=6, ncols=1, figsize=(10,20), sharex=True, sharey=False)
        fig.suptitle(name, usetex=False)

        ax[0].set_ylabel(r'DigiLock_PID1_locked', usetex=False)
        ax[0].plot(df_orig['Timestamp'], df_orig['DigiLock_PID1_locked'])
        ax[0].plot(df_redu['Timestamp'], df_redu['DigiLock_PID1_locked'])
        ax[0].set_ylim((4.9, 5))

        ax[1].set_ylabel(r'numberAtom', usetex=False)
        ax[1].plot(df_orig['Timestamp'], df_orig['numberAtom'])
        ax[1].plot(df_redu['Timestamp'], df_redu['numberAtom'])
        avg = np.mean(df_redu['numberAtom'])
        std = np.std(df_redu['numberAtom'])
        ax[1].set_ylim((avg-4*std, avg+4*std))

        ax[2].set_ylabel(r'tempXAtom', usetex=False)
        ax[2].plot(df_orig['Timestamp'], df_orig['tempXAtom'])
        ax[2].plot(df_redu['Timestamp'], df_redu['tempXAtom'])
        avg = np.mean(df_redu['tempXAtom'])
        std = np.std(df_redu['tempXAtom'])
        ax[2].set_ylim((avg-4*std, avg+4*std))

        ax[3].set_ylabel(r'tempYAtom')
        ax[3].plot(df_orig['Timestamp'], df_orig['tempYAtom'])
        ax[3].plot(df_redu['Timestamp'], df_redu['tempYAtom'])
        avg = np.mean(df_redu['tempYAtom'])
        std = np.std(df_redu['tempYAtom'])
        ax[3].set_ylim((avg-4*std, avg+4*std))

        ax[4].set_ylabel(r'Spec_Power [V]', usetex=False)
        ax[4].plot(df_orig['Timestamp'], df_orig['Spec_Power'])
        ax[4].plot(df_redu['Timestamp'], df_redu['Spec_Power'])
        avg = np.mean(df_redu['Spec_Power'])
        std = np.std(df_redu['Spec_Power'])
        ax[4].set_ylim((avg-4*std, avg+4*std))

        ax[5].set_ylabel(r'UV_Power [V]', usetex=False)
        ax[5].plot(df_orig['Timestamp'], df_orig['UV_Power'])
        ax[5].plot(df_redu['Timestamp'], df_redu['UV_Power'])
        avg = np.mean(df_redu['UV_Power'])
        std = np.std(df_redu['UV_Power'])
        ax[5].set_ylim((avg-4*std, avg+4*std))

        #plt.tight_layout()
        plt.show()
    
    # Drop unused data columns
    df_reduced.drop(columns=['AI3', 'AI4', 'AI5', 'AI6', 'AI7'], inplace=True)
    
    return df_reduced

pol_reduced = reduce_data(pol_data, POL_NAME, True)
unpol_reduced = reduce_data(unpol_data, UNPOL_NAME, True)

# %% [markdown]
# ### Aggregrate data

# %%
def aggregrate_data(df_data, indVar):
    df_grouped = df_data.groupby(by=indVar, as_index=False, sort=True)
    
    #df_out = df_grouped.agg([np.mean, np.std])
    df_out = df_grouped.agg({'sfiIntegral': [np.mean, np.std],
                             'UV_Power': [np.mean, np.std],
                             'Spec_Power': [np.mean, np.std],
                             'numberAtom': [np.mean, np.std],
                             'tempXAtom':  [np.mean, np.std],
                             'tempYAtom':  [np.mean, np.std]})
    
    df_out['count'] = df_grouped.size().values
    
    return df_out

indVar = ['imagevcoAtom']

pol_out = aggregrate_data(pol_reduced, indVar)
unpol_out = aggregrate_data(unpol_reduced, indVar)

# %% [markdown]
# ### Adjust counts due to MCP saturation

# %%
# Using the MCP saturation curve taken on 2019/03/27 by varying the UV power, we can account for the non-linear detection.

def mcp_saturation(df):
    df_temp = df
    observed_counts = unumpy.uarray(df_temp['sfiIntegral','mean'], df_temp['sfiIntegral','std'])
    observed_counts = observed_counts/NUM_EXPOSURES
    
    corrected_counts = -SATURATION_A*unumpy.log(1-observed_counts/SATURATION_A)
    corrected_counts = NUM_EXPOSURES*corrected_counts
    
    df_temp['sfiIntegral_linearized','mean'] = unumpy.nominal_values(corrected_counts)
    df_temp['sfiIntegral_linearized', 'std'] = unumpy.std_devs(corrected_counts)
    
    return df_temp

pol_out = mcp_saturation(pol_out)
unpol_out = mcp_saturation(unpol_out)

# %% [markdown]
# ### Calculate detunings

# %%
def calc_detuning(df, atomic, zeeman, order):
    df['detuning'] = order*2*(df['imagevcoAtom'] - (atomic + order*zeeman))
    
    return df

pol_out = calc_detuning(pol_out, ATOMIC, ZEEMAN, ORDER)
unpol_out = calc_detuning(unpol_out, ATOMIC, 0, ORDER)

# %%
plt.figure()
plt.plot(pol_out['detuning'], pol_out['sfiIntegral_linearized']['mean'])
plt.plot(unpol_out['detuning'], unpol_out['sfiIntegral_linearized']['mean'])
plt.yscale('log')
plt.title(SET_NAME)
plt.xlabel('Detuning [MHz]')
plt.ylabel('Total MCS counts')
plt.show()

# %% [markdown]
# # Analyzing the data

# %%
pol_data = pol_out
unpol_data = unpol_out

# %% [markdown]
# ### Adjust counts based on 689 nm and UV intensities

# %%
def adjust_for_intensities(df):
    df_temp = df
    
    raw_sfiIntegral = unumpy.uarray(df_temp['sfiIntegral_linearized', 'mean'], df_temp['sfiIntegral_linearized', 'std'])
    raw_UV_Power = unumpy.uarray(df_temp['UV_Power', 'mean'], df_temp['UV_Power', 'std'])
    raw_Spec_Power = unumpy.uarray(df_temp['Spec_Power', 'mean'], df_temp['Spec_Power', 'std'])
    
    adjusted_sfiIntegral = raw_sfiIntegral/raw_UV_Power/raw_Spec_Power
    
    df_temp['sfiIntegral_adjusted', 'mean'] = unumpy.nominal_values(adjusted_sfiIntegral)
    df_temp['sfiIntegral_adjusted', 'std'] = unumpy.std_devs(adjusted_sfiIntegral)
    
    return df_temp

# Correcting for 320 nm and 689 nm intensities point-by-point

pol_data = adjust_for_intensities(pol_data)
unpol_data = adjust_for_intensities(unpol_data)

# %%
# Plotting results after adjusting for 320 nm and 689 nm powers

plt.figure(figsize=(10,6))
plt.errorbar(pol_data['detuning'], pol_data['sfiIntegral_adjusted', 'mean'], 
             yerr=pol_data['sfiIntegral_adjusted', 'std'],
             fmt='.-', capsize=2, label='Polarized')
plt.errorbar(unpol_data['detuning'], unpol_data['sfiIntegral_adjusted', 'mean'], 
             yerr=unpol_data['sfiIntegral_adjusted', 'std'],
             fmt='.-', capsize=2, label='Unpolarized')
plt.gca().set_yscale('log')
plt.title(SET_NAME)
plt.xlabel('Detuning [MHz]')
plt.ylabel('Adjusted counts')
plt.legend()
plt.show()

# %% [markdown]
# # Plots for PhD thesis

# %%
## Constants
#B_bias = ufloat(1.1882,0.0020) # [G] bias field extracted from Zeeman shift of 5s37s state in 84Sr
B_bias = ufloat(1.05,0.0020) # [G]
mu0 = (ufloat(1.39962449361,0.00000000042)*1E10)*(1E-4)*(1E-6) # [MHz/G] Bohr magneton
gF = 4/11 # g-factor for 5s37s, 3S1, F=11/2

# %% [markdown]
# ### Fitting unpolarized data

# %%
data = unpol_data
plot_components = True
plot_initial_guess = True

# Choosing a range to fit over
xmin = min(data['detuning'])
xmax = max(data['detuning'])

xdata = data[(xmin <= data['detuning']) & (data['detuning'] <= xmax)]['detuning']
ydata = data[(xmin <= data['detuning']) & (data['detuning'] <= xmax)]['sfiIntegral_adjusted', 'mean']
ydata_unc = data[(xmin <= data['detuning']) & (data['detuning'] <= xmax)]['sfiIntegral_adjusted', 'std']

# Specify fit model
bg = PolynomialModel(degree=0, prefix='bg_')
d0 = PseudoVoigtModel(prefix='d0_')
d1 = PseudoVoigtModel(prefix='d1_')
d2 = PseudoVoigtModel(prefix='d2_')
d3 = PseudoVoigtModel(prefix='d3_')
d4 = PseudoVoigtModel(prefix='d4_')
d5 = PseudoVoigtModel(prefix='d5_')
d6 = PseudoVoigtModel(prefix='d6_')
d7 = PseudoVoigtModel(prefix='d7_')
d8 = PseudoVoigtModel(prefix='d8_')
d9 = PseudoVoigtModel(prefix='d9_')
d10 = PseudoVoigtModel(prefix='d10_')
d11 = PseudoVoigtModel(prefix='d11_')

fit_model = bg + d0 + d1 + d2 + d3 + d4 + d5 + d6 + d7 + d8 + d9 + d10 + d11
fit_params = fit_model.make_params()

#fit_params['bg_c0'].set(min(ydata), max=100, vary=True)
fit_params['bg_c0'].set(0, min=0, vary=True)
#fit_params['bg_c1'].set(2, vary=True)
#fit_params['bg_c2'].set(0, vary=True)

amplitude_scale = 1/7
sigma = 0.1
center_radius = 0.15
vary_center = True
vary_sigma = True
vary_amp = True

# m_F = -11/2 state
mF = -11/2
zs = mu0*B_bias*gF*mF
zs = zs.nominal_value
fit_params['d0_center'].set(zs, vary=vary_center, min=zs-center_radius, max=zs+center_radius)
fit_params['d0_amplitude'].set(3E1*amplitude_scale, min=0.1, max=50, vary=vary_amp)
fit_params['d0_sigma'].set(sigma, min=0.05, max=3*sigma, vary=vary_sigma)
fit_params['d0_fraction'].set(0.2, vary=True)

# m_F = -9/2 state
mF = -9/2
zs = mu0*B_bias*gF*mF
zs = zs.nominal_value
fit_params['d1_center'].set(zs, vary=vary_center, min=zs-center_radius, max=zs+center_radius)
fit_params['d1_amplitude'].set(1E3*amplitude_scale, min=0, vary=vary_amp)
fit_params['d1_sigma'].set(sigma, min=0.05, max=3*sigma, vary=vary_sigma)

# m_F = -7/2 state
mF = -7/2
zs = mu0*B_bias*gF*mF
zs = zs.nominal_value
fit_params['d2_center'].set(zs, vary=vary_center, min=zs-center_radius, max=zs+center_radius)
fit_params['d2_amplitude'].set(1E3*amplitude_scale, min=0, vary=vary_amp)
fit_params['d2_sigma'].set(sigma, min=0, max=3*sigma, vary=vary_sigma)

# m_F = -5/2 state
mF = -5/2
zs = mu0*B_bias*gF*mF
zs = zs.nominal_value
fit_params['d3_center'].set(zs, vary=vary_center, min=zs-center_radius, max=zs+center_radius)
fit_params['d3_amplitude'].set(7E2*amplitude_scale, min=0, vary=vary_amp)
fit_params['d3_sigma'].set(sigma, min=0.05, max=3*sigma, vary=vary_sigma)

# m_F = -3/2 state
mF = -3/2
zs = mu0*B_bias*gF*mF
zs = zs.nominal_value
fit_params['d4_center'].set(zs, vary=vary_center, min=zs-center_radius, max=zs+center_radius)
fit_params['d4_amplitude'].set(4E2*amplitude_scale, min=0, vary=vary_amp)
fit_params['d4_sigma'].set(sigma, min=0.05, max=3*sigma, vary=vary_sigma)

# m_F = -1/2 state
mF = -1/2
zs = mu0*B_bias*gF*mF
zs = zs.nominal_value
fit_params['d5_center'].set(zs, vary=vary_center, min=zs-center_radius, max=zs+center_radius)
fit_params['d5_amplitude'].set(100*amplitude_scale, min=0, vary=vary_amp)
fit_params['d5_sigma'].set(sigma, min=0.05, max=3*sigma, vary=vary_sigma)

# m_F = 1/2 state
mF = 1/2
zs = mu0*B_bias*gF*mF
zs = zs.nominal_value
fit_params['d6_center'].set(zs, vary=vary_center, min=zs-center_radius, max=zs+center_radius)
fit_params['d6_amplitude'].set(100*amplitude_scale, min=0, vary=vary_amp)
fit_params['d6_sigma'].set(sigma, min=0.05, max=3*sigma, vary=vary_sigma)

# m_F = 3/2 state
mF = 3/2
zs = mu0*B_bias*gF*mF
zs = zs.nominal_value
fit_params['d7_center'].set(zs, vary=vary_center, min=zs-center_radius, max=zs+center_radius)
fit_params['d7_amplitude'].set(6E2*amplitude_scale, min=0, vary=vary_amp)
fit_params['d7_sigma'].set(sigma, min=0.05, max=3*sigma, vary=vary_sigma)

# m_F = 5/2 state
mF = 5/2
zs = mu0*B_bias*gF*mF
zs = zs.nominal_value
fit_params['d8_center'].set(zs, vary=vary_center, min=zs-center_radius, max=zs+center_radius)
fit_params['d8_amplitude'].set(1E3*amplitude_scale, min=0, vary=vary_amp)
fit_params['d8_sigma'].set(sigma, min=0.05, max=3*sigma, vary=vary_sigma)

# m_F = 7/2 state
mF = 7/2
zs = mu0*B_bias*gF*mF
zs = zs.nominal_value
fit_params['d9_center'].set(zs, vary=vary_center, min=zs-center_radius, max=zs+center_radius)
fit_params['d9_amplitude'].set(1.25E3*amplitude_scale, min=0, vary=vary_amp)
fit_params['d9_sigma'].set(sigma, min=0.05, max=3*sigma, vary=vary_sigma)

# m_F = 9/2 state
mF = 9/2
zs = mu0*B_bias*gF*mF
zs = zs.nominal_value
fit_params['d10_center'].set(zs, vary=vary_center, min=zs-center_radius, max=zs+center_radius)
fit_params['d10_amplitude'].set(1.5E3*amplitude_scale, min=0, vary=vary_amp)
fit_params['d10_sigma'].set(sigma, min=0.05, max=3*sigma, vary=vary_sigma)

# m_F = 11/2 state
mF = 11/2
zs = mu0*B_bias*gF*mF
zs = zs.nominal_value
fit_params['d11_center'].set(zs, vary=vary_center, min=zs-center_radius, max=zs+center_radius)
fit_params['d11_amplitude'].set(3E1*amplitude_scale, min=0.1, max=50, vary=vary_amp)
fit_params['d11_sigma'].set(sigma, min=0, max=3*sigma, vary=vary_sigma)

# Initial guess
xfit = np.linspace(min(xdata), max(xdata), num=1000, endpoint=True)
yinit = fit_model.eval(fit_params, x=xfit)

# Plotting output
if plot_initial_guess:
    [fig, axs] = plt.subplots(nrows=2, ncols=1, sharex=True, sharey=False, figsize=(8,8))

    axs[0].errorbar(xdata, ydata, yerr=ydata_unc, capsize=3, label='data')
    axs[0].set_ylabel('Counts (linear)')

    axs[1].set_yscale('log')
    axs[1].errorbar(xdata, ydata, yerr=ydata_unc, capsize=3, label='data')
    axs[1].set_ylabel('Counts (log)')
    axs[1].set_ylim(bottom=1)

    if plot_initial_guess:
        for ax in axs:
            ax.plot(xfit, yinit, '-.', label='init')
    
    fig.suptitle(r'Initial guess')
    plt.xlabel('Detuning [MHz]')
    plt.show()

# Fitting
fit_result = fit_model.fit(ydata, fit_params, x=xdata)
#dely = fit_result.eval_uncertainty(x=xdata)
yfit = fit_model.eval(fit_result.params, x=xfit)

print(fit_result.fit_report())

# Plotting output
[fig, axs] = plt.subplots(nrows=2, ncols=1, sharex=True, sharey=False, figsize=(8,8))

axs[0].errorbar(xdata, ydata, yerr=ydata_unc, capsize=3, label='data')
axs[0].plot(xfit, yfit, label='fit')
axs[0].set_xlabel('Detuning [MHz]')
axs[0].set_ylabel('Counts (linear)')
axs[0].set_ylim(top=1000)

axs[1].set_yscale('log')
axs[1].errorbar(xdata, ydata, yerr=ydata_unc, capsize=3, label='data')
axs[1].plot(xfit, yfit, label='fit')
axs[1].set_xlabel('Detuning [MHz]')
axs[1].set_ylabel('Counts (log)')
axs[1].set_ylim(bottom=1)

if plot_components:
    # generate components
    fit_comps = fit_result.eval_components(x=xfit)
    
    for key in fit_comps.keys():
        for ax in axs:
            ax.plot(xfit, fit_comps[key], '--')

fig.suptitle(r'Fitted results')
plt.show()

unpol_fit_result = fit_result
# Out:
# [[Model]]
#     ((((((((((((Model(polynomial, prefix='bg_') + Model(pvoigt, prefix='d0_')) + Model(pvoigt, prefix='d1_')) + Model(pvoigt, prefix='d2_')) + Model(pvoigt, prefix='d3_')) + Model(pvoigt, prefix='d4_')) + Model(pvoigt, prefix='d5_')) + Model(pvoigt, prefix='d6_')) + Model(pvoigt, prefix='d7_')) + Model(pvoigt, prefix='d8_')) + Model(pvoigt, prefix='d9_')) + Model(pvoigt, prefix='d10_')) + Model(pvoigt, prefix='d11_'))
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 3060
#     # data points      = 75
#     # variables        = 49
#     chi-square         = 19829.9095
#     reduced chi-square = 762.688827
#     Akaike info crit   = 516.309391
#     Bayesian info crit = 629.866308
# ##  Warning: uncertainties could not be estimated:
#     bg_c0:          at initial value
#     bg_c0:          at boundary
#     d0_fraction:    at boundary
#     d0_sigma:       at boundary
#     d6_fraction:    at boundary
#     d6_center:      at initial value
#     d9_fraction:    at boundary
# [[Variables]]
#     bg_c0:          0.00000000 (init = 0)
#     d0_fraction:    9.0483e-15 (init = 0.2)
#     d0_sigma:       0.05000000 (init = 0.1)
#     d0_center:     -2.89637979 (init = -2.939211)
#     d0_amplitude:   0.28613189 (init = 4.285714)
#     d1_fraction:    0.64198135 (init = 0.5)
#     d1_sigma:       0.09235978 (init = 0.1)
#     d1_center:     -2.37599701 (init = -2.404809)
#     d1_amplitude:   169.552310 (init = 142.8571)
#     d2_fraction:    0.85700045 (init = 0.5)
#     d2_sigma:       0.09950515 (init = 0.1)
#     d2_center:     -1.87250816 (init = -1.870407)
#     d2_amplitude:   223.190108 (init = 142.8571)
#     d3_fraction:    0.35152950 (init = 0.5)
#     d3_sigma:       0.12333305 (init = 0.1)
#     d3_center:     -1.32873761 (init = -1.336005)
#     d3_amplitude:   156.190315 (init = 100)
#     d4_fraction:    0.33421349 (init = 0.5)
#     d4_sigma:       0.11323831 (init = 0.1)
#     d4_center:     -0.79466846 (init = -0.8016031)
#     d4_amplitude:   79.9057323 (init = 57.14286)
#     d5_fraction:    0.11244165 (init = 0.5)
#     d5_sigma:       0.11201322 (init = 0.1)
#     d5_center:     -0.26001558 (init = -0.267201)
#     d5_amplitude:   15.5161624 (init = 14.28571)
#     d6_fraction:    1.7079e-10 (init = 0.5)
#     d6_sigma:       0.10919104 (init = 0.1)
#     d6_center:      0.26720104 (init = 0.267201)
#     d6_amplitude:   14.5562398 (init = 14.28571)
#     d7_fraction:    0.68170542 (init = 0.5)
#     d7_sigma:       0.11069308 (init = 0.1)
#     d7_center:      0.78406579 (init = 0.8016031)
#     d7_amplitude:   107.175885 (init = 85.71429)
#     d8_fraction:    0.68380633 (init = 0.5)
#     d8_sigma:       0.10014927 (init = 0.1)
#     d8_center:      1.34191331 (init = 1.336005)
#     d8_amplitude:   216.707048 (init = 142.8571)
#     d9_fraction:    2.9814e-11 (init = 0.5)
#     d9_sigma:       0.13762974 (init = 0.1)
#     d9_center:      1.84181717 (init = 1.870407)
#     d9_amplitude:   251.468376 (init = 178.5714)
#     d10_fraction:   0.12864095 (init = 0.5)
#     d10_sigma:      0.13168832 (init = 0.1)
#     d10_center:     2.36670666 (init = 2.404809)
#     d10_amplitude:  284.757043 (init = 214.2857)
#     d11_fraction:   6.1878e-07 (init = 0.5)
#     d11_sigma:      0.15442215 (init = 0.1)
#     d11_center:     2.84292077 (init = 2.939211)
#     d11_amplitude:  6.84728582 (init = 4.285714)
#     d0_fwhm:        0.10000000 == '2.0000000*d0_sigma'
#     d0_height:      2.68802964 == '(((1-d0_fraction)*d0_amplitude)/(d0_sigma*sqrt(pi/log(2)))+(d0_fraction*d0_amplitude)/(pi*d0_sigma))'
#     d1_fwhm:        0.18471957 == '2.0000000*d1_sigma'
#     d1_height:      683.859611 == '(((1-d1_fraction)*d1_amplitude)/(d1_sigma*sqrt(pi/log(2)))+(d1_fraction*d1_amplitude)/(pi*d1_sigma))'
#     d2_fwhm:        0.19901030 == '2.0000000*d2_sigma'
#     d2_height:      762.533313 == '(((1-d2_fraction)*d2_amplitude)/(d2_sigma*sqrt(pi/log(2)))+(d2_fraction*d2_amplitude)/(pi*d2_sigma))'
#     d3_fwhm:        0.24666609 == '2.0000000*d3_sigma'
#     d3_height:      527.452537 == '(((1-d3_fraction)*d3_amplitude)/(d3_sigma*sqrt(pi/log(2)))+(d3_fraction*d3_amplitude)/(pi*d3_sigma))'
#     d4_fwhm:        0.22647663 == '2.0000000*d4_sigma'
#     d4_height:      295.745790 == '(((1-d4_fraction)*d4_amplitude)/(d4_sigma*sqrt(pi/log(2)))+(d4_fraction*d4_amplitude)/(pi*d4_sigma))'
#     d5_fwhm:        0.22402644 == '2.0000000*d5_sigma'
#     d5_height:      62.7075394 == '(((1-d5_fraction)*d5_amplitude)/(d5_sigma*sqrt(pi/log(2)))+(d5_fraction*d5_amplitude)/(pi*d5_sigma))'
#     d6_fwhm:        0.21838207 == '2.0000000*d6_sigma'
#     d6_height:      62.6181172 == '(((1-d6_fraction)*d6_amplitude)/(d6_sigma*sqrt(pi/log(2)))+(d6_fraction*d6_amplitude)/(pi*d6_sigma))'
#     d7_fwhm:        0.22138616 == '2.0000000*d7_sigma'
#     d7_height:      354.857117 == '(((1-d7_fraction)*d7_amplitude)/(d7_sigma*sqrt(pi/log(2)))+(d7_fraction*d7_amplitude)/(pi*d7_sigma))'
#     d8_fwhm:        0.20029855 == '2.0000000*d8_sigma'
#     d8_height:      792.364567 == '(((1-d8_fraction)*d8_amplitude)/(d8_sigma*sqrt(pi/log(2)))+(d8_fraction*d8_amplitude)/(pi*d8_sigma))'
#     d9_fwhm:        0.27525948 == '2.0000000*d9_sigma'
#     d9_height:      858.240268 == '(((1-d9_fraction)*d9_amplitude)/(d9_sigma*sqrt(pi/log(2)))+(d9_fraction*d9_amplitude)/(pi*d9_sigma))'
#     d10_fwhm:       0.26337664 == '2.0000000*d10_sigma'
#     d10_height:     973.581955 == '(((1-d10_fraction)*d10_amplitude)/(d10_sigma*sqrt(pi/log(2)))+(d10_fraction*d10_amplitude)/(pi*d10_sigma))'
#     d11_fwhm:       0.30884431 == '2.0000000*d11_sigma'
#     d11_height:     20.8279516 == '(((1-d11_fraction)*d11_amplitude)/(d11_sigma*sqrt(pi/log(2)))+(d11_fraction*d11_amplitude)/(pi*d11_sigma))'

# %%
print('Center mF=-11/2: ' + str(unpol_fit_result.params['d0_center'].value))
print('Center mF=-9/2: ' + str(unpol_fit_result.params['d1_center'].value))
print('Center mF=-7/2: ' + str(unpol_fit_result.params['d2_center'].value))
print('Center mF=-5/2: ' + str(unpol_fit_result.params['d3_center'].value))
print('Center mF=-3/2: ' + str(unpol_fit_result.params['d4_center'].value))
print('Center mF=-1/2: ' + str(unpol_fit_result.params['d5_center'].value))
print('Center mF=1/2: ' + str(unpol_fit_result.params['d6_center'].value))
print('Center mF=3/2: ' + str(unpol_fit_result.params['d7_center'].value))
print('Center mF=5/2: ' + str(unpol_fit_result.params['d8_center'].value))
print('Center mF=7/2: ' + str(unpol_fit_result.params['d9_center'].value))
print('Center mF=9/2: ' + str(unpol_fit_result.params['d10_center'].value))
print('Center mF=11/2: ' + str(unpol_fit_result.params['d11_center'].value))
# Out:
# Center mF=-11/2: -2.8963797939091287
# Center mF=-9/2: -2.3759970084395436
# Center mF=-7/2: -1.8725081587676387
# Center mF=-5/2: -1.3287376079930024
# Center mF=-3/2: -0.7946684622658116
# Center mF=-1/2: -0.2600155824911478
# Center mF=1/2: 0.26720103968918185
# Center mF=3/2: 0.7840657862690192
# Center mF=5/2: 1.3419133091600288
# Center mF=7/2: 1.8418171677958632
# Center mF=9/2: 2.3667066608215084
# Center mF=11/2: 2.8429207677380925

# %%
print('Frac mF=-11/2: ' + str(unpol_fit_result.params['d0_fraction'].value))
print('Frac mF=-9/2: ' + str(unpol_fit_result.params['d1_fraction'].value))
print('Frac mF=-7/2: ' + str(unpol_fit_result.params['d2_fraction'].value))
print('Frac mF=-5/2: ' + str(unpol_fit_result.params['d3_fraction'].value))
print('Frac mF=-3/2: ' + str(unpol_fit_result.params['d4_fraction'].value))
print('Frac mF=-1/2: ' + str(unpol_fit_result.params['d5_fraction'].value))
print('Frac mF=1/2: ' + str(unpol_fit_result.params['d6_fraction'].value))
print('Frac mF=3/2: ' + str(unpol_fit_result.params['d7_fraction'].value))
print('Frac mF=5/2: ' + str(unpol_fit_result.params['d8_fraction'].value))
print('Frac mF=7/2: ' + str(unpol_fit_result.params['d9_fraction'].value))
print('Frac mF=9/2: ' + str(unpol_fit_result.params['d10_fraction'].value))
print('Frac mF=11/2: ' + str(unpol_fit_result.params['d11_fraction'].value))
# Out:
# Frac mF=-11/2: 9.048317650695026e-15
# Frac mF=-9/2: 0.6419813456434307
# Frac mF=-7/2: 0.8570004504214594
# Frac mF=-5/2: 0.3515295033823744
# Frac mF=-3/2: 0.33421348968133663
# Frac mF=-1/2: 0.11244164523947131
# Frac mF=1/2: 1.7078533032233167e-10
# Frac mF=3/2: 0.6817054245212614
# Frac mF=5/2: 0.683806326702779
# Frac mF=7/2: 2.9814040125586416e-11
# Frac mF=9/2: 0.12864094960135325
# Frac mF=11/2: 6.187764897691572e-07

# %% [markdown]
# ### Fitting polarized data

# %%
data = pol_data
plot_components = True
plot_initial_guess = True

# Choosing a range to fit over
xmin = min(data['detuning'])
xmax = max(data['detuning'])

xdata = data[(xmin <= data['detuning']) & (data['detuning'] <= xmax)]['detuning']
ydata = data[(xmin <= data['detuning']) & (data['detuning'] <= xmax)]['sfiIntegral_adjusted', 'mean']
ydata_unc = data[(xmin <= data['detuning']) & (data['detuning'] <= xmax)]['sfiIntegral_adjusted', 'std']

# Specify fit model
bg = PolynomialModel(degree=0, prefix='bg_')
d0 = PseudoVoigtModel(prefix='d0_')
d1 = PseudoVoigtModel(prefix='d1_')
d2 = PseudoVoigtModel(prefix='d2_')
d3 = PseudoVoigtModel(prefix='d3_')
d4 = PseudoVoigtModel(prefix='d4_')
d5 = PseudoVoigtModel(prefix='d5_')
d6 = PseudoVoigtModel(prefix='d6_')
d7 = PseudoVoigtModel(prefix='d7_')
d8 = PseudoVoigtModel(prefix='d8_')
d9 = PseudoVoigtModel(prefix='d9_')
d10 = PseudoVoigtModel(prefix='d10_')
d11 = PseudoVoigtModel(prefix='d11_')

fit_model = bg + d0 + d1 + d2 + d3 + d4 + d5 + d6 + d7 + d8 + d9 + d10 + d11
fit_params = fit_model.make_params()

#fit_params['bg_c0'].set(min(ydata), max=100, vary=True)
fit_params['bg_c0'].set(1, min=0, max=2, vary=True)
#fit_params['bg_c1'].set(2, vary=True)
#fit_params['bg_c2'].set(0, vary=True)

amplitude_scale = 1/7
sigma = 0.1
center_radius = 0.15
vary_center = False
vary_sigma = False
vary_amp = True

# m_F = -11/2 state
mF = -11/2
zs = mu0*B_bias*gF*mF
zs = zs.nominal_value
fit_params['d0_center'].set(unpol_fit_result.params['d0_center'].value, vary=vary_center, min=zs-center_radius, max=zs+center_radius)
fit_params['d0_amplitude'].set(1*amplitude_scale, min=0, max=50, vary=vary_amp)
fit_params['d0_sigma'].set(unpol_fit_result.params['d0_sigma'].value, min=0, vary=vary_sigma)
fit_params['d0_fraction'].set(unpol_fit_result.params['d0_fraction'].value, vary=False)

# m_F = -9/2 state
mF = -9/2
zs = mu0*B_bias*gF*mF
zs = zs.nominal_value
fit_params['d1_center'].set(unpol_fit_result.params['d1_center'].value, vary=vary_center, min=zs-center_radius, max=zs+center_radius)
fit_params['d1_amplitude'].set(1*amplitude_scale, min=0, vary=vary_amp)
fit_params['d1_sigma'].set(unpol_fit_result.params['d1_sigma'].value, min=0, vary=vary_sigma)
fit_params['d1_fraction'].set(unpol_fit_result.params['d1_fraction'].value, vary=False)

# m_F = -7/2 state
mF = -7/2
zs = mu0*B_bias*gF*mF
zs = zs.nominal_value
fit_params['d2_center'].set(unpol_fit_result.params['d2_center'].value, vary=vary_center, min=zs-center_radius, max=zs+center_radius)
fit_params['d2_amplitude'].set(2*amplitude_scale, min=0, vary=vary_amp)
fit_params['d2_sigma'].set(unpol_fit_result.params['d2_sigma'].value, min=0, vary=vary_sigma)
fit_params['d2_fraction'].set(unpol_fit_result.params['d2_fraction'].value, vary=False)

# m_F = -5/2 state
mF = -5/2
zs = mu0*B_bias*gF*mF
zs = zs.nominal_value
fit_params['d3_center'].set(unpol_fit_result.params['d3_center'].value, vary=vary_center, min=zs-center_radius, max=zs+center_radius)
fit_params['d3_amplitude'].set(3*amplitude_scale, min=0, vary=vary_amp)
fit_params['d3_sigma'].set(unpol_fit_result.params['d3_sigma'].value, min=0, vary=vary_sigma)
fit_params['d3_fraction'].set(unpol_fit_result.params['d3_fraction'].value, vary=False)

# m_F = -3/2 state
mF = -3/2
zs = mu0*B_bias*gF*mF
zs = zs.nominal_value
fit_params['d4_center'].set(unpol_fit_result.params['d4_center'].value, vary=vary_center, min=zs-center_radius, max=zs+center_radius)
fit_params['d4_amplitude'].set(4*amplitude_scale, min=0, vary=vary_amp)
fit_params['d4_sigma'].set(unpol_fit_result.params['d4_sigma'].value, min=0, vary=vary_sigma)
fit_params['d4_fraction'].set(unpol_fit_result.params['d4_fraction'].value, vary=False)

# m_F = -1/2 state
mF = -1/2
zs = mu0*B_bias*gF*mF
zs = zs.nominal_value
fit_params['d5_center'].set(unpol_fit_result.params['d5_center'].value, vary=vary_center, min=zs-center_radius, max=zs+center_radius)
fit_params['d5_amplitude'].set(4*amplitude_scale, min=0, vary=vary_amp)
fit_params['d5_sigma'].set(unpol_fit_result.params['d5_sigma'].value, min=0, vary=vary_sigma)
fit_params['d5_fraction'].set(unpol_fit_result.params['d5_fraction'].value, vary=False)

# m_F = 1/2 state
mF = 1/2
zs = mu0*B_bias*gF*mF
zs = zs.nominal_value
fit_params['d6_center'].set(unpol_fit_result.params['d6_center'].value, vary=vary_center, min=zs-center_radius, max=zs+center_radius)
fit_params['d6_amplitude'].set(6*amplitude_scale, min=0, vary=vary_amp)
fit_params['d6_sigma'].set(unpol_fit_result.params['d6_sigma'].value, min=0, vary=vary_sigma)
fit_params['d6_fraction'].set(unpol_fit_result.params['d6_fraction'].value, vary=False)

# m_F = 3/2 state
mF = 3/2
zs = mu0*B_bias*gF*mF
zs = zs.nominal_value
fit_params['d7_center'].set(fit_result.params['d7_center'].value, vary=vary_center, min=zs-center_radius, max=zs+center_radius)
fit_params['d7_amplitude'].set(7*amplitude_scale, min=0, vary=vary_amp)
fit_params['d7_sigma'].set(fit_result.params['d7_sigma'].value, min=0, vary=vary_sigma)
fit_params['d7_fraction'].set(unpol_fit_result.params['d7_fraction'].value, vary=False)

# m_F = 5/2 state
mF = 5/2
zs = mu0*B_bias*gF*mF
zs = zs.nominal_value
fit_params['d8_center'].set(unpol_fit_result.params['d8_center'].value, vary=vary_center, min=zs-center_radius, max=zs+center_radius)
fit_params['d8_amplitude'].set(8*amplitude_scale, min=0, vary=vary_amp)
fit_params['d8_sigma'].set(unpol_fit_result.params['d8_sigma'].value, min=0, vary=vary_sigma)
fit_params['d8_fraction'].set(unpol_fit_result.params['d8_fraction'].value, vary=False)

# m_F = 7/2 state
mF = 7/2
zs = mu0*B_bias*gF*mF
zs = zs.nominal_value
fit_params['d9_center'].set(unpol_fit_result.params['d9_center'].value, vary=vary_center, min=zs-center_radius, max=zs+center_radius)
fit_params['d9_amplitude'].set(1E1*amplitude_scale, min=0, vary=vary_amp)
fit_params['d9_sigma'].set(unpol_fit_result.params['d9_sigma'].value, min=0, vary=vary_sigma)
fit_params['d9_fraction'].set(unpol_fit_result.params['d9_fraction'].value, vary=False)

# m_F = 9/2 state
mF = 9/2
zs = mu0*B_bias*gF*mF
zs = zs.nominal_value
fit_params['d10_center'].set(unpol_fit_result.params['d10_center'].value, vary=vary_center, min=zs-center_radius, max=zs+center_radius)
fit_params['d10_amplitude'].set(1.5E4*amplitude_scale, min=0, vary=vary_amp)
fit_params['d10_sigma'].set(unpol_fit_result.params['d10_sigma'].value, min=0, vary=vary_sigma)
fit_params['d10_fraction'].set(unpol_fit_result.params['d10_fraction'].value, vary=False)

# m_F = 11/2 state
mF = 11/2
zs = mu0*B_bias*gF*mF
zs = zs.nominal_value
fit_params['d11_center'].set(unpol_fit_result.params['d11_center'].value, vary=vary_center, min=zs-center_radius, max=zs+center_radius)
fit_params['d11_amplitude'].set(1.2E1*amplitude_scale, min=0, max=50, vary=vary_amp)
fit_params['d11_sigma'].set(unpol_fit_result.params['d11_sigma'].value, min=0, vary=vary_sigma)
fit_params['d11_fraction'].set(unpol_fit_result.params['d11_fraction'].value, vary=False)

# Initial guess
xfit = np.linspace(min(xdata), max(xdata), num=1000, endpoint=True)
yinit = fit_model.eval(fit_params, x=xfit)

# Plotting output
if plot_initial_guess:
    [fig, axs] = plt.subplots(nrows=2, ncols=1, sharex=True, sharey=False, figsize=(8,8))

    axs[0].errorbar(xdata, ydata, yerr=ydata_unc, capsize=3, label='data')
    axs[0].set_ylabel('Counts (linear)')

    axs[1].set_yscale('log')
    axs[1].errorbar(xdata, ydata, yerr=ydata_unc, capsize=3, label='data')
    axs[1].set_ylabel('Counts (log)')
    axs[1].set_ylim(bottom=1)

    if plot_initial_guess:
        for ax in axs:
            ax.plot(xfit, yinit, '-.', label='init')
    
    fig.suptitle(r'Initial guess')
    plt.xlabel('Detuning [MHz]')
    plt.show()

# Fitting
fit_result = fit_model.fit(ydata, fit_params, x=xdata)
#dely = fit_result.eval_uncertainty(x=xdata)
yfit = fit_model.eval(fit_result.params, x=xfit)

print(fit_result.fit_report())

# Plotting output
[fig, axs] = plt.subplots(nrows=2, ncols=1, sharex=True, sharey=False, figsize=(8,8))

axs[0].errorbar(xdata, ydata, yerr=ydata_unc, capsize=3, label='data')
axs[0].plot(xfit, yfit, label='fit')
axs[0].set_xlabel('Detuning [MHz]')
axs[0].set_ylabel('Counts (linear)')
axs[0].set_ylim(top=1000)

axs[1].set_yscale('log')
axs[1].errorbar(xdata, ydata, yerr=ydata_unc, capsize=3, label='data')
axs[1].plot(xfit, yfit, label='fit')
axs[1].set_xlabel('Detuning [MHz]')
axs[1].set_ylabel('Counts (log)')
axs[1].set_ylim(bottom=1)

if plot_components:
    # generate components
    fit_comps = fit_result.eval_components(x=xfit)
    
    for key in fit_comps.keys():
        for ax in axs:
            ax.plot(xfit, fit_comps[key], '--')

fig.suptitle(r'Fitted results')
plt.show()

pol_fit_result = fit_result
# Out:
# [[Model]]
#     ((((((((((((Model(polynomial, prefix='bg_') + Model(pvoigt, prefix='d0_')) + Model(pvoigt, prefix='d1_')) + Model(pvoigt, prefix='d2_')) + Model(pvoigt, prefix='d3_')) + Model(pvoigt, prefix='d4_')) + Model(pvoigt, prefix='d5_')) + Model(pvoigt, prefix='d6_')) + Model(pvoigt, prefix='d7_')) + Model(pvoigt, prefix='d8_')) + Model(pvoigt, prefix='d9_')) + Model(pvoigt, prefix='d10_')) + Model(pvoigt, prefix='d11_'))
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 370
#     # data points      = 75
#     # variables        = 13
#     chi-square         = 1878584.62
#     reduced chi-square = 30299.7520
#     Akaike info crit   = 785.640581
#     Bayesian info crit = 815.767926
# [[Variables]]
#     bg_c0:          1.99999041 +/- 73.0799597 (3654.02%) (init = 1)
#     d0_fraction:    9.048318e-15 (fixed)
#     d0_sigma:       0.05 (fixed)
#     d0_center:     -2.89638 (fixed)
#     d0_amplitude:   0.00385507 +/- 18.9541183 (491667.16%) (init = 0.1428571)
#     d1_fraction:    0.6419813 (fixed)
#     d1_sigma:       0.09235978 (fixed)
#     d1_center:     -2.375997 (fixed)
#     d1_amplitude:   0.13255205 +/- 39.3350973 (29675.21%) (init = 0.1428571)
#     d2_fraction:    0.8570005 (fixed)
#     d2_sigma:       0.09950515 (fixed)
#     d2_center:     -1.872508 (fixed)
#     d2_amplitude:   0.29039411 +/- 43.7528859 (15066.73%) (init = 0.2857143)
#     d3_fraction:    0.3515295 (fixed)
#     d3_sigma:       0.123333 (fixed)
#     d3_center:     -1.328738 (fixed)
#     d3_amplitude:   0.59121185 +/- 40.2391568 (6806.22%) (init = 0.4285714)
#     d4_fraction:    0.3342135 (fixed)
#     d4_sigma:       0.1132383 (fixed)
#     d4_center:     -0.7946685 (fixed)
#     d4_amplitude:   0.50067660 +/- 38.1547962 (7620.65%) (init = 0.5714286)
#     d5_fraction:    0.1124416 (fixed)
#     d5_sigma:       0.1120132 (fixed)
#     d5_center:     -0.2600156 (fixed)
#     d5_amplitude:   0.33789075 +/- 35.2509507 (10432.65%) (init = 0.5714286)
#     d6_fraction:    1.707853e-10 (fixed)
#     d6_sigma:       0.109191 (fixed)
#     d6_center:      0.267201 (fixed)
#     d6_amplitude:   0.77807314 +/- 33.0929147 (4253.19%) (init = 0.8571429)
#     d7_fraction:    0.6817054 (fixed)
#     d7_sigma:       0.1106931 (fixed)
#     d7_center:      0.7840658 (fixed)
#     d7_amplitude:   2.03572369 +/- 43.0657234 (2115.50%) (init = 1)
#     d8_fraction:    0.6838063 (fixed)
#     d8_sigma:       0.1001493 (fixed)
#     d8_center:      1.341913 (fixed)
#     d8_amplitude:   7.65064381 +/- 41.1731884 (538.17%) (init = 1.142857)
#     d9_fraction:    2.981404e-11 (fixed)
#     d9_sigma:       0.1376297 (fixed)
#     d9_center:      1.841817 (fixed)
#     d9_amplitude:   58.6192716 +/- 37.5270925 (64.02%) (init = 1.428571)
#     d10_fraction:   0.1286409 (fixed)
#     d10_sigma:      0.1316883 (fixed)
#     d10_center:     2.366707 (fixed)
#     d10_amplitude:  2285.59895 +/- 38.3659971 (1.68%) (init = 2142.857)
#     d11_fraction:   6.187765e-07 (fixed)
#     d11_sigma:      0.1544222 (fixed)
#     d11_center:     2.842921 (fixed)
#     d11_amplitude:  30.1773996 +/- 40.1468014 (133.04%) (init = 1.714286)
#     d0_fwhm:        0.10000000 +/- 0.00000000 (0.00%) == '2.0000000*d0_sigma'
#     d0_height:      0.03621597 +/- 178.062053 (491667.16%) == '(((1-d0_fraction)*d0_amplitude)/(d0_sigma*sqrt(pi/log(2)))+(d0_fraction*d0_amplitude)/(pi*d0_sigma))'
#     d1_fwhm:        0.18471957 +/- 0.00000000 (0.00%) == '2.0000000*d1_sigma'
#     d1_height:      0.53462554 +/- 158.651241 (29675.21%) == '(((1-d1_fraction)*d1_amplitude)/(d1_sigma*sqrt(pi/log(2)))+(d1_fraction*d1_amplitude)/(pi*d1_sigma))'
#     d2_fwhm:        0.19901030 +/- 0.00000000 (0.00%) == '2.0000000*d2_sigma'
#     d2_height:      0.99213710 +/- 149.482579 (15066.73%) == '(((1-d2_fraction)*d2_amplitude)/(d2_sigma*sqrt(pi/log(2)))+(d2_fraction*d2_amplitude)/(pi*d2_sigma))'
#     d3_fwhm:        0.24666609 +/- 0.00000000 (0.00%) == '2.0000000*d3_sigma'
#     d3_height:      1.99651427 +/- 135.887077 (6806.22%) == '(((1-d3_fraction)*d3_amplitude)/(d3_sigma*sqrt(pi/log(2)))+(d3_fraction*d3_amplitude)/(pi*d3_sigma))'
#     d4_fwhm:        0.22647663 +/- 0.00000000 (0.00%) == '2.0000000*d4_sigma'
#     d4_height:      1.85309607 +/- 141.217908 (7620.65%) == '(((1-d4_fraction)*d4_amplitude)/(d4_sigma*sqrt(pi/log(2)))+(d4_fraction*d4_amplitude)/(pi*d4_sigma))'
#     d5_fwhm:        0.22402644 +/- 0.00000000 (0.00%) == '2.0000000*d5_sigma'
#     d5_height:      1.36556302 +/- 142.464376 (10432.65%) == '(((1-d5_fraction)*d5_amplitude)/(d5_sigma*sqrt(pi/log(2)))+(d5_fraction*d5_amplitude)/(pi*d5_sigma))'
#     d6_fwhm:        0.21838207 +/- 0.00000000 (0.00%) == '2.0000000*d6_sigma'
#     d6_height:      3.34711957 +/- 142.359294 (4253.19%) == '(((1-d6_fraction)*d6_amplitude)/(d6_sigma*sqrt(pi/log(2)))+(d6_fraction*d6_amplitude)/(pi*d6_sigma))'
#     d7_fwhm:        0.22138616 +/- 0.00000000 (0.00%) == '2.0000000*d7_sigma'
#     d7_height:      6.74023860 +/- 142.589711 (2115.50%) == '(((1-d7_fraction)*d7_amplitude)/(d7_sigma*sqrt(pi/log(2)))+(d7_fraction*d7_amplitude)/(pi*d7_sigma))'
#     d8_fwhm:        0.20029855 +/- 0.00000000 (0.00%) == '2.0000000*d8_sigma'
#     d8_height:      27.9737052 +/- 150.545059 (538.17%) == '(((1-d8_fraction)*d8_amplitude)/(d8_sigma*sqrt(pi/log(2)))+(d8_fraction*d8_amplitude)/(pi*d8_sigma))'
#     d9_fwhm:        0.27525948 +/- 0.00000000 (0.00%) == '2.0000000*d9_sigma'
#     d9_height:      200.062609 +/- 128.076788 (64.02%) == '(((1-d9_fraction)*d9_amplitude)/(d9_sigma*sqrt(pi/log(2)))+(d9_fraction*d9_amplitude)/(pi*d9_sigma))'
#     d10_fwhm:       0.26337664 +/- 0.00000000 (0.00%) == '2.0000000*d10_sigma'
#     d10_height:     7814.44373 +/- 131.173025 (1.68%) == '(((1-d10_fraction)*d10_amplitude)/(d10_sigma*sqrt(pi/log(2)))+(d10_fraction*d10_amplitude)/(pi*d10_sigma))'
#     d11_fwhm:       0.30884431 +/- 0.00000000 (0.00%) == '2.0000000*d11_sigma'
#     d11_height:     91.7930746 +/- 122.117823 (133.04%) == '(((1-d11_fraction)*d11_amplitude)/(d11_sigma*sqrt(pi/log(2)))+(d11_fraction*d11_amplitude)/(pi*d11_sigma))'
# [[Correlations]] (unreported correlations are < 0.100)
#     C(bg_c0, d11_amplitude)        =  0.354
#     C(bg_c0, d7_amplitude)         =  0.341
#     C(bg_c0, d2_amplitude)         =  0.336
#     C(bg_c0, d10_amplitude)        =  0.332
#     C(bg_c0, d9_amplitude)         =  0.326
#     C(bg_c0, d8_amplitude)         =  0.325
#     C(bg_c0, d3_amplitude)         =  0.324
#     C(bg_c0, d4_amplitude)         =  0.321
#     C(bg_c0, d1_amplitude)         =  0.315
#     C(bg_c0, d5_amplitude)         =  0.310
#     C(bg_c0, d6_amplitude)         =  0.294
#     C(bg_c0, d0_amplitude)         =  0.192
#     C(d7_amplitude, d11_amplitude) =  0.119
#     C(d2_amplitude, d11_amplitude) =  0.118
#     C(d9_amplitude, d11_amplitude) =  0.116
#     C(d3_amplitude, d11_amplitude) =  0.114
#     C(d4_amplitude, d11_amplitude) =  0.113
#     C(d2_amplitude, d7_amplitude)  =  0.112
#     C(d8_amplitude, d11_amplitude) =  0.111
#     C(d1_amplitude, d11_amplitude) =  0.111
#     C(d2_amplitude, d10_amplitude) =  0.111
#     C(d5_amplitude, d11_amplitude) =  0.110
#     C(d7_amplitude, d10_amplitude) =  0.109
#     C(d2_amplitude, d9_amplitude)  =  0.109
#     C(d2_amplitude, d8_amplitude)  =  0.108
#     C(d3_amplitude, d7_amplitude)  =  0.108
#     C(d3_amplitude, d10_amplitude) =  0.107
#     C(d4_amplitude, d10_amplitude) =  0.106
#     C(d1_amplitude, d7_amplitude)  =  0.106
#     C(d3_amplitude, d9_amplitude)  =  0.105
#     C(d7_amplitude, d9_amplitude)  =  0.105
#     C(d4_amplitude, d9_amplitude)  =  0.104
#     C(d1_amplitude, d10_amplitude) =  0.104
#     C(d6_amplitude, d11_amplitude) =  0.104
#     C(d4_amplitude, d7_amplitude)  =  0.104
#     C(d3_amplitude, d8_amplitude)  =  0.104
#     C(d5_amplitude, d10_amplitude) =  0.103
#     C(d1_amplitude, d9_amplitude)  =  0.102
#     C(d4_amplitude, d8_amplitude)  =  0.102
#     C(d1_amplitude, d8_amplitude)  =  0.101
#     C(d5_amplitude, d9_amplitude)  =  0.101
#     C(d2_amplitude, d5_amplitude)  =  0.100

# %%
# Calculate populations
total_pop = np.sum([pol_fit_result.params['d0_amplitude'].value,
                    pol_fit_result.params['d1_amplitude'].value,
                    pol_fit_result.params['d2_amplitude'].value,
                    pol_fit_result.params['d3_amplitude'].value,
                    pol_fit_result.params['d4_amplitude'].value,
                    pol_fit_result.params['d5_amplitude'].value,
                    pol_fit_result.params['d6_amplitude'].value,
                    pol_fit_result.params['d7_amplitude'].value,
                    pol_fit_result.params['d8_amplitude'].value,
                    pol_fit_result.params['d9_amplitude'].value,
                    pol_fit_result.params['d10_amplitude'].value,
                    pol_fit_result.params['d11_amplitude'].value])

print('Pop in mF=9/2: ' + str(pol_fit_result.params['d10_amplitude'].value/total_pop))
# Out:
# Pop in mF=9/2: 0.957633138909067

# %% [markdown]
# ## Plot for PhD thesis

# %%
sns.set_context('talk')

[fig, axs] = plt.subplots(figsize=(8, 6), sharex=True)

###############################################
# Plot options
cp = sns.color_palette("Paired")

pol_data_opt = {'fmt':'o',
                'markersize':5,
                'capsize':3,
                'markeredgecolor':cp[1],
                'ecolor':cp[1],
                'markerfacecolor':cp[0]}

pol_fit_opt = {'color':cp[1]}

unpol_data_opt = {'fmt':'s',
                  'markersize':5,
                  'capsize':3,
                  'markeredgecolor':cp[3],
                  'ecolor':cp[3],
                  'markerfacecolor':cp[2]}

unpol_fit_opt = {'color':cp[3]}

xfit = np.linspace(-4, 4, 1000, endpoint=True)

###############################################
# Plotting polarized data + fit

# Polarized experiment results
data = pol_data
xdata = data['detuning']
ydata = data['sfiIntegral_adjusted', 'mean']
ydata_unc = data['sfiIntegral_adjusted', 'std']/np.sqrt(data['count'])
axs.errorbar(xdata, ydata, yerr=ydata_unc, **pol_data_opt, label=r'Spin-Polarized')

# Polarized fit results
fit_result = pol_fit_result
fit_comps = fit_result.eval_components(x=xfit)
yfit = sum(fit_comps[key] for key in fit_comps.keys())
axs.plot(xfit, yfit, **pol_fit_opt)



###############################################
# Plotting unpolarized data + fit

# Unpolarized experiment results
data = unpol_data
xdata = data['detuning']
ydata = data['sfiIntegral_adjusted', 'mean']
ydata_unc = data['sfiIntegral_adjusted', 'std']/np.sqrt(data['count'])
axs.errorbar(xdata, ydata, yerr=ydata_unc, **unpol_data_opt, label=r'Unpolarized')

# Unpolarized fit results
fit_result = unpol_fit_result
fit_comps = fit_result.eval_components(x=xfit)
yfit = sum(fit_comps[key] for key in fit_comps.keys())
axs.plot(xfit, yfit, **unpol_fit_opt)

###############################################
# Figure options

#ax.set_xlim(min([min(pol_data['detuning']), min(unpol_data['detuning'])]), max([max(pol_data['detuning']), max(unpol_data['detuning'])]))
axs.set_xlim((-3.8, 3.8))
#ax.set_ylim((0.75E1, 1E4))
axs.set_yscale('log')
axs.tick_params(axis='both', which='both', direction='in', length=5,
               bottom=True, left=True, top=True, right=True)
    
    #ax.set_ylabel(r'Scaled MCP signal')

plt.xlabel(r'Detuning [\si{\MHz}]')
plt.ylabel(r'Scaled MCP signal')

plt.legend(frameon=False)

plt.savefig('n33-check_spin-polarization.pdf', bbox_inches='tight')
plt.savefig('n33-check_spin-polarization.png', bbox_inches='tight', transparent=True, dpi=1000)

plt.show()
