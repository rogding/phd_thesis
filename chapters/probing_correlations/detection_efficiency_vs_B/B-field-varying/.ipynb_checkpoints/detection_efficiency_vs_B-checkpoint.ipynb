# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import seaborn as sns

import os
import glob

# %%
# https://stackoverflow.com/questions/22348756/upright-mu-in-plot-label-retaining-original-tick-fonts
# https://stackoverflow.com/questions/2537868/sans-serif-math-with-latex-in-matplotlib

import matplotlib
from matplotlib import rc

matplotlib.rc('text', usetex = True)
matplotlib.rc('font', **{'family':'sans-serif'})

params = {'text.latex.preamble':[r'\usepackage{siunitx}',
                                 r'\usepackage{amsmath}',
                                 r'\usepackage{physics}',
                                 r'\usepackage{helvet}',
                                 r'\usepackage{sansmath}',
                                 r'\sansmath',
                                 r'\sisetup{detect-all}']}
plt.rcParams.update(params)

# %% [markdown]
# # Read in data from varying B-field

# %%
data_02V =
# Out:
# ['B-field-varying\\n37-Bfield_counting_efficiency-repitition_1.00000E+0_B_fieldX-1.00000E+0_18084009_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_1.00000E+0_B_fieldX-1.50000E+0_18084012_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_1.00000E+0_B_fieldX-2.00000E+0_18084015_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_1.00000E+0_B_fieldX-2.00000E-1_18084000_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_1.00000E+0_B_fieldX-2.50000E+0_08473500_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_1.00000E+0_B_fieldX-2.50000E+0_18084018_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_1.00000E+0_B_fieldX-2.50000E+0_23323010_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_1.00000E+0_B_fieldX-3.00000E+0_18084021_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_1.00000E+0_B_fieldX-3.00000E+0_23323000_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_1.00000E+0_B_fieldX-4.34000E-1_18084003_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_1.00000E+0_B_fieldX-7.50000E-1_18084006_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_1.00000E+1_B_fieldX-3.00000E+0_23323009_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_2.00000E+0_B_fieldX-1.00000E+0_18084010_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_2.00000E+0_B_fieldX-1.50000E+0_18084013_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_2.00000E+0_B_fieldX-2.00000E+0_18084016_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_2.00000E+0_B_fieldX-2.00000E-1_18084001_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_2.00000E+0_B_fieldX-2.50000E+0_08473501_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_2.00000E+0_B_fieldX-2.50000E+0_18084019_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_2.00000E+0_B_fieldX-2.50000E+0_23323011_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_2.00000E+0_B_fieldX-3.00000E+0_18084022_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_2.00000E+0_B_fieldX-3.00000E+0_23323001_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_2.00000E+0_B_fieldX-4.34000E-1_18084004_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_2.00000E+0_B_fieldX-7.50000E-1_18084007_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_3.00000E+0_B_fieldX-1.00000E+0_18084011_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_3.00000E+0_B_fieldX-1.50000E+0_18084014_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_3.00000E+0_B_fieldX-2.00000E+0_18084017_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_3.00000E+0_B_fieldX-2.00000E-1_18084002_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_3.00000E+0_B_fieldX-2.50000E+0_08473502_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_3.00000E+0_B_fieldX-2.50000E+0_18084020_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_3.00000E+0_B_fieldX-2.50000E+0_23323012_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_3.00000E+0_B_fieldX-3.00000E+0_18084023_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_3.00000E+0_B_fieldX-3.00000E+0_23323002_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_3.00000E+0_B_fieldX-4.34000E-1_18084005_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_3.00000E+0_B_fieldX-7.50000E-1_18084008_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_4.00000E+0_B_fieldX-2.50000E+0_08473503_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_4.00000E+0_B_fieldX-2.50000E+0_23323013_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_4.00000E+0_B_fieldX-3.00000E+0_23323003_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_5.00000E+0_B_fieldX-2.50000E+0_08473504_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_5.00000E+0_B_fieldX-3.00000E+0_23323004_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_6.00000E+0_B_fieldX-2.50000E+0_08473505_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_6.00000E+0_B_fieldX-3.00000E+0_23323005_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_7.00000E+0_B_fieldX-2.50000E+0_08473506_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_7.00000E+0_B_fieldX-3.00000E+0_23323006_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_8.00000E+0_B_fieldX-2.50000E+0_08473507_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_8.00000E+0_B_fieldX-3.00000E+0_23323007_out.csv',
#  'B-field-varying\\n37-Bfield_counting_efficiency-repitition_9.00000E+0_B_fieldX-3.00000E+0_23323008_out.csv']
