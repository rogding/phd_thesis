# %%
import numpy as np
from uncertainties import ufloat

# %% [markdown]
# # Constants

# %% [markdown]
# # $5s^2{}^{1}{S}_{0} \rightarrow 5s5p{}^{3}{P}_{1}$

# %%
# Isotope shifts and hyperfine constants from Bushaw2000.SAPB.55.1679

I = 9/2

# 87Sr hyperfine constants
A_5s5p_1P1 = ufloat(-3.334, 0.025)
B_5s5p_1P1 = ufloat(40.29, 0.21)

nu_87Sr_cg = ufloat(-44.6, 0.4)

J = 1
F = 7/2
K = F*(F+1) - I*(I+1) - J*(J+1)
nu_87Sr_5s5p_1P1_72 = (A_5s5p_1P1/2)*K + B_5s5p_1P1*(3/2*K*(K+1)-2*I*(I+1)*J*(J+1))/(4*I*(2*I-1)*J*(2*J-1))

J = 1
F = 11/2
K = F*(F+1) - I*(I+1) - J*(J+1)
nu_87Sr_5s5p_1P1_112 = (A_5s5p_1P1/2)*K + B_5s5p_1P1*(3/2*K*(K+1)-2*I*(I+1)*J*(J+1))/(4*I*(2*I-1)*J*(2*J-1))

J = 1
F = 9/2
K = F*(F+1) - I*(I+1) - J*(J+1)
nu_87Sr_5s5p_1P1_92 = (A_5s5p_1P1/2)*K + B_5s5p_1P1*(3/2*K*(K+1)-2*I*(I+1)*J*(J+1))/(4*I*(2*I-1)*J*(2*J-1))

print(nu_87Sr_5s5p_1P1_72)
print(nu_87Sr_5s5p_1P1_112)
print(nu_87Sr_5s5p_1P1_92)

print(nu_87Sr_5s5p_1P1_72 + nu_87Sr_cg)
print(nu_87Sr_5s5p_1P1_112 + nu_87Sr_cg)
print(nu_87Sr_5s5p_1P1_92 + nu_87Sr_cg)
# Out:
# 36.80+/-0.17
# -4.93+/-0.12
# -23.53+/-0.14
# -7.8+/-0.4
# -49.5+/-0.4
# -68.1+/-0.4
