# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
energy_levels = [['5s5s', '1S0', 0],
                 ['5s5p', '1P1', 21698.452],
                 ['5s5p', '3P2', 14898.545],
                 ['5s5p', '3P1', 14504.334],
                 ['5s5p', '3P0', 14317.507],
                 ['5s4d', '1D2', 20149.685],
                 ['5p5p', '3P2', 35674.637]]

energy_levels = pd.DataFrame(data=energy_levels, columns=['Series', 'Term', 'Energy'])

# %%
energy_levels
# Out:
#   Series Term     Energy
# 0   5s5s  1S0      0.000
# 1   5s5p  1P1  21698.452
# 2   5s5p  3P2  14898.545
# 3   5s5p  3P1  14504.334
# 4   5s5p  3P0  14317.507
# 5   5s4d  1D2  20149.685
# 6   5p5p  3P2  35674.637

# %%
# Example data
t = np.arange(0.0, 1.0 + 0.01, 0.01)
s = np.cos(4 * np.pi * t) + 2

plt_params = {'text.usetex':True, 
              'font.family':'serif',
              'text.latex.preamble':r'\usepackage{physics}'
                                    r'\usepackage{amssymb}'}

with plt.rc_context(plt_params):
    plt.xlabel(r'\textbf{time} (s)')
    plt.ylabel(r'\textit{voltage} (mV)',fontsize=16)
    plt.title(r"\TeX\ is Number "
          r"$\displaystyle\sum_{n=1}^\infty\frac{-e^{i\pi}}{2^n}$!",
          fontsize=16, color='gray')
    
    # Make room for the ridiculously large title.
    plt.subplots_adjust(top=0.8)
