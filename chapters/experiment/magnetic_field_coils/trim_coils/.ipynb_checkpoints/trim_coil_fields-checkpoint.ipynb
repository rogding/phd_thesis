# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Constants
mu0 = (4e-7*np.pi)/10000 # [G*m/A] vacuum permeability

# %%
# B-field due to a finite length wire
# r           : position at which to calculate field
# wire_params : 
# out         : B-field fector at specified r=[x,y,z]
def finite_wire(r, wire_params):
    [x, y, z] = r
    return 0

# %%
# X-axis rectangular coils (formerly Y-axis during construction)
# D : [m] coil separation. Used average of 13.25" (inner dim) and 14.25" (outer dim)
# L : [m] length, horizontal. Used average of 12.5" (inner dim) and 13.5" (outer dim)
# H : [m] height, vertical. Used average of 6" (inner dim) and 7" (outer dim)

D = 13.75*25.4/1000
L = 13*25.4/1000
H = 6.5*25.4/1000

# %%
# Y-axis rectangular coils (formerly X-axis during construction)
# D : [m] coil separation. Used average of 12.25" (inner dim) and 13.25" (outer dim)
# L : [m] length, horizontal. Used average of 12" (inner dim) and 13" (outer dim)
# H : [m] height, vertical. Used average of 6" (inner dim) and 7" (outer dim)

D = 12.75*25.4/1000
L = 12.5*25.4/1000
H = 6.5*25.4/1000

# %%
mu0-1.2566370614e-7
# Out:
# 1.1309733552959172e-06
