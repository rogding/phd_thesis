# %%
import numpy as np
from scipy import constants as spc 
from uncertainties import ufloat, ufloat_fromstr

# %%
print(np.mean([ufloat_fromstr('-1000470.8(2.4)'),ufloat_fromstr('-1000473.673(11)')]))
# Out:
# -1000472.2+/-1.2

# %%
mr88
# Out:
# 87.9056125+/-1.2e-06
