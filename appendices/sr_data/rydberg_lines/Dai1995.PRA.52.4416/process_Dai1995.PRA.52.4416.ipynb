# %% [markdown]
# # Processing data from Dai1995.PRA.52.4416
#
# Perturbed 5snd 1,3D2 Rydberg series of Sr
# C. J. Dai
# Phys. Rev. A 52, 4416 (1995)
# https://doi.org/10.1103/PhysRevA.52.4416

# %%
import os
import glob

import pandas as pd
import numpy as np
from uncertainties import ufloat, unumpy

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_context('talk')

# %% [markdown]
# ## Constants
# Constants to be set for each particular data set.

# %%
# Constants that should not need changing
C = 299792458 # Speed of light in [m/s]

# CODATA 2014 constants
RY_inf = ufloat(10973731.568508, 0.000065)/100 # Rydberg constant [/cm]
AMU = ufloat(1.660539040, 0.000000020)*1E-27 # Atomic mass unit [kg]
M_E = ufloat(9.10938356, 0.00000011)*1E-31 # Electron mass [kg]

M_88 = ufloat(87905612.256, 0.006)*1E-6*AMU
M_87 = ufloat(86908877.496, 0.005)*1E-6*AMU
M_86 = ufloat(85909260.726, 0.006)*1E-6*AMU
M_84 = ufloat(83913419.1, 1.3)*1E-6*AMU

out = pd.DataFrame(columns=['Series','n', 'Term', 'Label', 'E_exp', 'E_exp_unc', 'Isotope', 'Reference'])

# %%
# Constants which should change depending on the data set being analyzed
REFERENCE = 'Dai1995.PRA.52.4416'
PATH_TO_RAW_DATA = os.path.join('source','Dai1995.PRA.52.4416*.csv')
OUTPUT_FILE_NAME = REFERENCE + '-analyzed.csv'

ISOTOPE = 88

I_S = ufloat(1377012721, 10)/(C*100/1E6) # Given ionization limit for 88Sr in paper.

#RY_Sr = 109736.631 # Rydberg constant in [/cm]
RY_Sr = RY_inf*(M_88/(M_E + M_88))

# %% [markdown]
# ## Read in all the files to a single DataFrame

# %%
# Goes through all listed .csv files and returns data in a single DataFrame

source_list = glob.glob(PATH_TO_RAW_DATA)

def gather_data(file_list):
    
    # Read in .csv files in to single DataFrame
    out = pd.DataFrame()
    for file_name in file_list:
        df = pd.read_csv(file_name)
        
        out = pd.concat([out, df], join='outer', ignore_index=True, sort=False)
    
    return out

data = gather_data(source_list)

# %% [markdown]
# ## Process data
# May need to tweak depending on the data set being analyzed.

# %%
# They claim a linewidth better than 0.5 /cm.
data['E_Expt_unc'] = 0.5

# %% [markdown]
# ### Put data in to a standardized table

# %%
# Only keep data that's newly presented (some data tables include previously measured data)
out['Term'] = data[data['New'] & ~pd.isna(data['New'])]['Term']
out['n'] = data[data['New'] & ~pd.isna(data['New'])]['n']
out['E_exp'] = data[data['New'] & ~pd.isna(data['New'])]['E_Expt']
out['E_exp_unc'] = data[data['New'] & ~pd.isna(data['New'])]['E_Expt_unc']

# Set the isotope
out['Isotope'] = ISOTOPE
out['Reference'] = REFERENCE

# Specify the series based on the term
for idx, row in out.iterrows():
    if row['Term'] == '3S1':
        out.at[idx, 'Series'] = '5sns'
    elif row['Term'] == '1D2' or row['Term'] == '3D1' or row['Term'] == '3D2' or row['Term'] == '3D3':
        out.at[idx, 'Series'] = '5snd'
    else:
        print('Error with assigning series')

# Label the states
for idx, row in out.iterrows():
    out.at[idx, 'Label'] = row['Series'].replace('n', str(row['n']))

# %% [markdown]
# ### Calculate quantum defect

# %%
n = out['n']
E_exp = unumpy.uarray(out['E_exp'], out['E_exp_unc'])
delta_expt = n - unumpy.sqrt(RY_Sr/(I_S-E_exp))

out['delta_exp'] = unumpy.nominal_values(delta_expt)
out['delta_exp_unc'] = unumpy.std_devs(delta_expt)

# %%
plt_kwargs = {'capsize':4,
              'fmt':'.'}

nrows = len(out['Term'].unique())

if nrows > 1:
    [fig, axs] = plt.subplots(nrows=nrows, ncols=1, figsize=(10,3*nrows), sharex=True, sharey=False)

    for i, T in enumerate(out['Term'].unique()):
        x = out[out['Term'] == T]['n']
        y = out[out['Term'] == T]['delta_exp']
        yerr = out[out['Term'] == T]['delta_exp_unc']
        axs[i].errorbar(x, y, yerr=yerr, label=T, **plt_kwargs, color=sns.color_palette()[i])
        axs[i].legend()
        axs[i].tick_params(axis='both', direction='in')
        axs[i].set_ylabel(r'$\delta$')

    plt.xlabel(r'$n$')
    plt.show()

else:
    plt.figure(figsize=(10,3))
    
    T = out['Term'].unique()[0]
    
    x = out['n']
    y = out['delta_exp']
    yerr = out['delta_exp_unc']
    plt.errorbar(x, y, yerr=yerr, label=T, **plt_kwargs, color=sns.color_palette()[0])
    plt.legend()
    plt.gca().tick_params(axis='both', direction='in')

    plt.xlabel(r'$n$')
    plt.ylabel(r'$\delta$')
    plt.show()

# %% [markdown]
# ### Write out processed data as .csv

# %%
out.to_csv(OUTPUT_FILE_NAME, index=False)

# %%
# Typo for n=50, 5snd, 1D2. E_expt should be 45883.86
# Typo for n=19, 5snd, 1D2. E_expt should be 45542.36
out[out['Term']=='1D2']
# Out:
#    Series   n Term  Label     E_exp  E_exp_unc  Isotope            Reference  \
# 3    5snd   9  1D2   5s9d  43755.98        0.5       88  Dai1995.PRA.52.4416
# 4    5snd  10  1D2  5s10d  44241.86        0.5       88  Dai1995.PRA.52.4416
# 5    5snd  11  1D2  5s11d  44578.62        0.5       88  Dai1995.PRA.52.4416
# 6    5snd  12  1D2  5s12d  44829.47        0.5       88  Dai1995.PRA.52.4416
# 7    5snd  13  1D2  5s13d  45011.81        0.5       88  Dai1995.PRA.52.4416
# 8    5snd  14  1D2  5s14d  45153.03        0.5       88  Dai1995.PRA.52.4416
# 9    5snd  15  1D2  5s15d  45263.62        0.5       88  Dai1995.PRA.52.4416
# 10   5snd  16  1D2  5s16d  45362.17        0.5       88  Dai1995.PRA.52.4416
# 11   5snd  17  1D2  5s17d  45433.26        0.5       88  Dai1995.PRA.52.4416
# 12   5snd  18  1D2  5s18d  45492.74        0.5       88  Dai1995.PRA.52.4416
# 13   5snd  19  1D2  5s19d  45542.36        0.5       88  Dai1995.PRA.52.4416
# 14   5snd  20  1D2  5s20d  45584.23        0.5       88  Dai1995.PRA.52.4416
# 15   5snd  21  1D2  5s21d  45619.63        0.5       88  Dai1995.PRA.52.4416
# 16   5snd  22  1D2  5s22d  45650.27        0.5       88  Dai1995.PRA.52.4416
# 17   5snd  23  1D2  5s23d  45676.49        0.5       88  Dai1995.PRA.52.4416
# 18   5snd  24  1D2  5s24d  45699.31        0.5       88  Dai1995.PRA.52.4416
# 19   5snd  25  1D2  5s25d  45719.16        0.5       88  Dai1995.PRA.52.4416
# 20   5snd  26  1D2  5s26d  45736.83        0.5       88  Dai1995.PRA.52.4416
# 21   5snd  27  1D2  5s27d  45752.24        0.5       88  Dai1995.PRA.52.4416
# 22   5snd  28  1D2  5s28d  45765.77        0.5       88  Dai1995.PRA.52.4416
# 23   5snd  29  1D2  5s29d  45778.02        0.5       88  Dai1995.PRA.52.4416
# 24   5snd  30  1D2  5s30d  45788.92        0.5       88  Dai1995.PRA.52.4416
# 25   5snd  31  1D2  5s31d  45798.69        0.5       88  Dai1995.PRA.52.4416
# 26   5snd  32  1D2  5s32d  45807.43        0.5       88  Dai1995.PRA.52.4416
# 27   5snd  33  1D2  5s33d  45815.53        0.5       88  Dai1995.PRA.52.4416
# 28   5snd  34  1D2  5s34d  45822.51        0.5       88  Dai1995.PRA.52.4416
# 29   5snd  35  1D2  5s35d  45829.34        0.5       88  Dai1995.PRA.52.4416
# 30   5snd  36  1D2  5s36d  45835.36        0.5       88  Dai1995.PRA.52.4416
# 31   5snd  37  1D2  5s37d  45840.43        0.5       88  Dai1995.PRA.52.4416
# 32   5snd  38  1D2  5s38d  45845.73        0.5       88  Dai1995.PRA.52.4416
# 33   5snd  39  1D2  5s39d  45850.54        0.5       88  Dai1995.PRA.52.4416
# 34   5snd  40  1D2  5s40d  45854.81        0.5       88  Dai1995.PRA.52.4416
# 35   5snd  41  1D2  5s41d  45858.76        0.5       88  Dai1995.PRA.52.4416
# 36   5snd  42  1D2  5s42d  45862.41        0.5       88  Dai1995.PRA.52.4416
# 37   5snd  43  1D2  5s43d  45865.81        0.5       88  Dai1995.PRA.52.4416
# 38   5snd  44  1D2  5s44d  45868.99        0.5       88  Dai1995.PRA.52.4416
# 39   5snd  45  1D2  5s45d  45871.94        0.5       88  Dai1995.PRA.52.4416
# 40   5snd  46  1D2  5s46d  45874.61        0.5       88  Dai1995.PRA.52.4416
# 41   5snd  47  1D2  5s47d  45877.16        0.5       88  Dai1995.PRA.52.4416
# 42   5snd  48  1D2  5s48d  45879.56        0.5       88  Dai1995.PRA.52.4416
# 43   5snd  49  1D2  5s49d  45881.82        0.5       88  Dai1995.PRA.52.4416
# 44   5snd  50  1D2  5s50d  45883.86        0.5       88  Dai1995.PRA.52.4416
#
#     delta_exp  delta_exp_unc
# 3    1.898920       0.000816
# 4    1.942715       0.001192
# 5    1.996035       0.001663
# 6    2.024351       0.002262
# 7    2.080825       0.002966
# 8    2.132489       0.003808
# 9    2.188528       0.004791
# 10   2.125196       0.006085
# 11   2.169645       0.007431
# 12   2.197856       0.008990
# 13   2.222298       0.010759
# 14   2.241562       0.012759
# 15   2.262916       0.014986
# 16   2.271004       0.017495
# 17   2.284198       0.020253
# 18   2.292982       0.023302
# 19   2.304226       0.026633
# 20   2.300095       0.030327
# 21   2.306222       0.034304
# 22   2.322089       0.038572
# 23   2.321497       0.043259
# 24   2.325316       0.048288
# 25   2.330605       0.053684
# 26   2.343471       0.059422
# 27   2.331271       0.065717
# 28   2.370536       0.072088
# 29   2.337302       0.079386
# 30   2.337382       0.086902
# 31   2.420008       0.094203
# 32   2.376016       0.102995
# 33   2.341854       0.112228
# 34   2.344126       0.121643
# 35   2.344724       0.131588
# 36   2.346778       0.142044
# 37   2.344088       0.153095
# 38   2.333972       0.164791
# 39   2.326290       0.177039
# 40   2.348278       0.189493
# 41   2.348539       0.202813
# 42   2.341998       0.216840
# 43   2.329150       0.231593
# 44   2.354550       0.246407
