# %%
"""
Overall analysis program
"""

import os.path
import pandas as pd
import scipy.constants as spc
from uncertainties import ufloat
import numpy as np

# %%
# Names of data files in source/ subdirectory
REF = ['arm1979.JOSA.69.211',
       'bei1982.OC.42.19',
       'bei1982.PS.26.183',
       'dai1995.JQSRT.54.1019',
       'esh1977.PRA.15.1920',
       'ewa1976.JPB.9.L437',
       'gar1968.JPB.1.106',
       'phi2007.OC.279.141',
       'kun1993.ZPD.27.111',
       'rub1978.PS.18.196']

# Output DataFrame output column names
COLUMNS = {'Series':       str(),
           'n':            int(),
           'Term':         str(), 
           'Label':        str(),
           'E_exp':        float(),
           'E_exp_unc':    float(),
           'Isotope':      int(),
           'Ref':          str()}

combined = pd.DataFrame(columns=COLUMNS)

for ref in REF:
    file_name = os.path.join(ref, ref+'-analyzed.csv')
    
    if os.path.isfile(file_name):
        combined = combined.append(pd.read_csv(file_name), sort=False)
        
    else:
        print('Warning, no analyzed .csv for: '+ref)
# Out:
# Warning, no analyzed .csv for: gar1968.JPB.1.106
# Warning, no analyzed .csv for: rub1978.PS.18.196

# %%
# Working on individual series and terms

data_sets = [['5sns', '1S0'],
             ['5sns', '3S1']]

for series, term in data_sets:
    
    temp = combined[(combined['Series']==series) & (combined['Term']==term)]
    #temp.reset_index(inplace=True, drop=True)
    
    ref_list = temp['Ref'].unique().tolist()
    n_list = temp['n'].unique()
    
    # Column headers to use output dataframe
    header = ['Series', 'n', 'Term', 'Avg', 'Unc']
    
    out = pd.DataFrame(columns=header)
    
    # Merges DFs based on Series, n, Term. Relabels E_exp and E_exp_unc with reference names
    for ref in ref_list:
        temp2 = temp[temp['Ref']==ref][['Series', 'n', 'Term', 'E_exp', 'E_exp_unc']]
        temp2.rename(index=str, columns={'E_exp':'E_'+ref, 'E_exp_unc': 'dE_'+ref}, inplace=True)
        
        out = out.merge(temp2, on=['Series', 'n', 'Term'], how='outer')

# %%
for index, row in out.iterrows():
    x = ufloat(row['E_'+'bei1982.PS.26.183'], row['dE_'+'bei1982.PS.26.183'])

# %%
x
# Out:
# 45868.83+/-0.15

# %%
test = temp[temp['Ref'] == 'bei1982.PS.26.183']
test2 = temp[temp['Ref'] == 'kun1993.ZPD.27.111']

# %%
test3 = out.merge(test, on=['Series', 'n', 'Term'], how='outer')
test3 = test3.merge(test2, on=['Series', 'n', 'Term'], how='outer')

# %%
test
# Out:
#    Series   n Term  Label     E_exp  E_exp_unc Isotope                Ref
# 0    5sns  11  3S1  5s11s  44043.27       0.15      88  bei1982.PS.26.183
# 1    5sns  12  3S1  5s12s  44456.38       0.15      88  bei1982.PS.26.183
# 2    5sns  13  3S1  5s13s  44747.68       0.15      88  bei1982.PS.26.183
# 3    5sns  14  3S1  5s14s  44960.22       0.15      88  bei1982.PS.26.183
# 4    5sns  15  3S1  5s15s  45120.41       0.15      88  bei1982.PS.26.183
# 5    5sns  16  3S1  5s16s  45243.88       0.15      88  bei1982.PS.26.183
# 6    5sns  17  3S1  5s17s  45341.28       0.15      88  bei1982.PS.26.183
# 7    5sns  18  3S1  5s18s  45419.29       0.15      88  bei1982.PS.26.183
# 8    5sns  19  3S1  5s19s  45482.85       0.15      88  bei1982.PS.26.183
# 9    5sns  20  3S1  5s20s  45535.26       0.15      88  bei1982.PS.26.183
# 10   5sns  21  3S1  5s21s  45579.11       0.15      88  bei1982.PS.26.183
# 11   5sns  22  3S1  5s22s  45615.88       0.15      88  bei1982.PS.26.183
# 12   5sns  23  3S1  5s23s  45647.23       0.15      88  bei1982.PS.26.183
# 13   5sns  24  3S1  5s24s  45674.29       0.15      88  bei1982.PS.26.183
# 14   5sns  25  3S1  5s25s  45697.74       0.15      88  bei1982.PS.26.183
# 15   5sns  26  3S1  5s26s  45718.04       0.15      88  bei1982.PS.26.183
# 16   5sns  27  3S1  5s27s  45735.67       0.15      88  bei1982.PS.26.183
# 17   5sns  28  3S1  5s28s  45751.32       0.15      88  bei1982.PS.26.183
# 18   5sns  29  3S1  5s29s  45765.12       0.15      88  bei1982.PS.26.183
# 19   5sns  30  3S1  5s30s  45777.40       0.15      88  bei1982.PS.26.183
# 20   5sns  31  3S1  5s31s  45788.41       0.15      88  bei1982.PS.26.183
# 21   5sns  32  3S1  5s32s  45798.22       0.15      88  bei1982.PS.26.183
# 22   5sns  33  3S1  5s33s  45807.34       0.15      88  bei1982.PS.26.183
# 23   5sns  34  3S1  5s34s  45815.26       0.15      88  bei1982.PS.26.183
# 24   5sns  35  3S1  5s35s  45822.59       0.15      88  bei1982.PS.26.183
# 25   5sns  36  3S1  5s36s  45829.13       0.15      88  bei1982.PS.26.183
# 26   5sns  37  3S1  5s37s  45835.15       0.15      88  bei1982.PS.26.183
# 27   5sns  38  3S1  5s38s  45840.69       0.15      88  bei1982.PS.26.183
# 28   5sns  39  3S1  5s39s  45845.75       0.15      88  bei1982.PS.26.183
# 29   5sns  40  3S1  5s40s  45850.41       0.15      88  bei1982.PS.26.183
# 30   5sns  41  3S1  5s41s  45854.74       0.15      88  bei1982.PS.26.183
# 31   5sns  42  3S1  5s42s  45858.65       0.15      88  bei1982.PS.26.183
# 32   5sns  43  3S1  5s43s  45862.48       0.15      88  bei1982.PS.26.183
# 33   5sns  44  3S1  5s44s  45865.77       0.15      88  bei1982.PS.26.183
# 34   5sns  45  3S1  5s45s  45868.83       0.15      88  bei1982.PS.26.183
